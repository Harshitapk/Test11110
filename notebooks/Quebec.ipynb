# %%
import requests
import json
import pandas as pd

YELP_API_KEY = YELP_API_KEY
API_ENDPOINT = 'https://api.yelp.com/v3/businesses/search'

# Yelp API endpoint URL for exploring restaurants
yelp_url = 'https://api.yelp.com/v3/businesses/search'
yelp_headers = {
    "Authorization": f"Bearer {YELP_API_KEY}"
}

venues_data_list = []

yelp_params = {
    'location': 'Duberger–Les Saules,Quebec',
    'radius': 2000,  # Radius for restaurant search (adjust as needed)
    'categories': 'restaurants',
    'limit': 50,  # Number of restaurants to retrieve (adjust as needed)
    }

yelp_response = requests.get(API_ENDPOINT, params=yelp_params, headers=yelp_headers)

# Check if the Yelp response is successful
if yelp_response.status_code == 200:
    yelp_data = json.loads(yelp_response.text)
    for business in yelp_data.get('businesses', []):
        categories = [category.get('title') for category in business.get('categories', [])]
        cuisine_keywords = ['coffee','fast food', 'burgers', 'sushi', 'pizza', 'sandwiches', 'pub', 'bar','cafe','steak','seafood','dessert','beer']
        nationality_keywords = ['european','greek','african','mexican','venezuelan','vietnamese','malaysian','caribbean','persian','filipino','irish','british','scottish','ethiopian','american', 'japanese', 'mediterranean', 'thai', 'french', 'italian', 'middle eastern','canadian','asian','indian','chinese','german','korean','peruvian']
        cuisine_list = []
        nationality_list = []
        for category in categories:
            category_lower = category.lower()
            if any(keyword in category_lower for keyword in cuisine_keywords):
                cuisine_list.append(category)
            elif any(keyword in category_lower for keyword in nationality_keywords):
                nationality_list.append(category)
        restaurant_details = {
            'Name': business.get('name'),
            'Categories': ', '.join(categories),
            'Cuisine Types': ', '.join(cuisine_list),
            'Nationalities': ', '.join(nationality_list),
            'Rating': business.get('rating'),
            'Address': ', '.join([business.get('location', {}).get('address1'), business.get('location', {}).get('city')]) or 'N/A',
            'Res_Latitude': business.get('coordinates', {}).get('latitude'),
            'Res_Longitude': business.get('coordinates', {}).get('longitude'),
            'Reviews': business.get('review_count'),
            'Distance': business.get('distance'),
            'Phone': business.get('phone') or 'N/A',
            'Closed': business.get('is_closed'),
            'Price': business.get('price') or 'N/A',
        }
        venues_data_list.append(restaurant_details)

# Create a DataFrame from the restaurant data list
Duberger = pd.DataFrame(venues_data_list)


Duberger.shape
# Out:
# (5, 13)

# %%
Quebec_df = pd.concat([Vanier,
Limoilou,
Sillery,
Plateau,
Chouinard,
Lairet,
Citadelle,
Bergerville,
roch,
Montmorency,
Bourg,
Abraham,
Blanc,
Auvergne,
laval,
Cageux,
Rouge,
Lebourgneuf,
American,
Charlesbourg],axis=0)

# %%
Quebec_df.shape
# Out:
# (705, 13)

# %%
Quebec_no_duplicates = Quebec_df.drop_duplicates(subset=['Name', 'Categories', 'Cuisine Types', 'Nationalities','Address'])

# %%
Quebec_no_duplicates.shape
# Out:
# (357, 13)

# %%
Quebec_no_duplicates.reset_index(drop=True, inplace=True)
Quebec_no_duplicates
# Out:
#                      Name                                   Categories  \
# 0          Le Fin Gourmet  Canadian (New), Burgers, Breakfast & Brunch
# 1              L'Oeuforie              Steakhouses, Breakfast & Brunch
# 2            Casa Grecque                                        Greek
# 3         Le Soleil Rouge                           Breakfast & Brunch
# 4             Chez Ashton               Burgers, Hot Dogs, Poutineries
# ..                    ...                                          ...
# 352              Le Dijon                                       French
# 353         Pizza Passion                                        Pizza
# 354          Sushi Oshima                         Japanese, Sushi Bars
# 355         Pizza Passion                                        Pizza
# 356  Restaurant Normandin
#
#     Cuisine Types   Nationalities  Rating  \
# 0         Burgers  Canadian (New)     4.5
# 1     Steakhouses                     4.0
# 2                           Greek     4.0
# 3                                     5.0
# 4         Burgers                     4.0
# ..            ...             ...     ...
# 352                        French     4.0
# 353         Pizza                     4.5
# 354    Sushi Bars        Japanese     4.5
# 355         Pizza                     4.0
# 356                                   3.5
#
#                                           Address  Res_Latitude  \
# 0                774 Rue Raoul-Jobin, Quebec City     46.806850
# 1           850 Boulevard Pierre-Bertrand, Vanier     46.826615
# 2      955 Boulevard Pierre-Bertrand, Quebec City     46.827170
# 3           380A Avenue Turcotte, Ville de Québec     46.821480
# 4        550 Boulevard Wilfrid-Hamel, Quebec City     46.821440
# ..                                            ...           ...
# 352              7900 Rue du Marigot, Quebec City     46.883743
# 353     1450 Boulevard Père-Lelièvre, Quebec City     46.883630
# 354             16, rue Georges-Muir, Quebec City     46.899349
# 355         5425 Avenue des Platanes, Quebec City     46.883628
# 356  15021 Boulevard Henri Bourassa, Charlesbourg     46.881569
#
#      Res_Longitude  Reviews     Distance         Phone  Closed Price
# 0       -71.245840       15  2175.481757  +14186825849   False    $$
# 1       -71.273329        7   897.748230  +14186814419   False    $$
# 2       -71.275680        5  1108.444575  +14185271210   False   N/A
# 3       -71.257520        2   450.240401           N/A   False   N/A
# 4       -71.251607        1   908.555722  +14186480895   False   N/A
# ..             ...      ...          ...           ...     ...   ...
# 352     -71.307739        5  1538.975367  +14187812988   False    $$
# 353     -71.282465        3  1789.002373  +14187812555   False   N/A
# 354     -71.305344        3   659.016424  +14188413838   False   N/A
# 355     -71.282464        2  1789.220449  +14186224447   False    $$
# 356     -71.287918        3  1768.215045  +14186267216   False    $$
#
# [357 rows x 13 columns]

# %%
Quebec_no_duplicates.to_csv('Quebec.csv', index=False)

# %%
import pandas as pd
Quebec1_df = pd.read_csv('../data/Quebec.csv')
Quebec1_df.head()
# Out:
#               Name                                   Categories Cuisine Types  \
# 0   Le Fin Gourmet  Canadian (New), Burgers, Breakfast & Brunch       Burgers
# 1       L'Oeuforie              Steakhouses, Breakfast & Brunch   Steakhouses
# 2     Casa Grecque                                        Greek           NaN
# 3  Le Soleil Rouge                           Breakfast & Brunch           NaN
# 4      Chez Ashton               Burgers, Hot Dogs, Poutineries       Burgers
#
#     Nationalities  Rating                                     Address  \
# 0  Canadian (New)     4.5            774 Rue Raoul-Jobin, Quebec City
# 1             NaN     4.0       850 Boulevard Pierre-Bertrand, Vanier
# 2           Greek     4.0  955 Boulevard Pierre-Bertrand, Quebec City
# 3             NaN     5.0       380A Avenue Turcotte, Ville de Québec
# 4             NaN     4.0    550 Boulevard Wilfrid-Hamel, Quebec City
#
#    Res_Latitude  Res_Longitude  Reviews     Distance         Phone  Closed  \
# 0     46.806850     -71.245840       15  2175.481757  1.418683e+10   False
# 1     46.826615     -71.273329        7   897.748230  1.418681e+10   False
# 2     46.827170     -71.275680        5  1108.444575  1.418527e+10   False
# 3     46.821480     -71.257520        2   450.240401           NaN   False
# 4     46.821440     -71.251607        1   908.555722  1.418648e+10   False
#
#   Price
# 0    $$
# 1    $$
# 2   NaN
# 3   NaN
# 4   NaN

# %%
Quebec1_df['Price'].fillna(method='ffill', inplace=True)
columns_to_fill = ['Nationalities','Phone','Categories']
Quebec1_df[columns_to_fill] = Quebec1_df[columns_to_fill].fillna('NA')


import pandas as pd
import numpy as np
def fill_cuisine(row):
    if pd.notnull(row['Cuisine Types']):
        return row['Cuisine Types']
    categories = row['Categories'].split(', ')
    if len(categories) > 0:
        return categories[0]
    return np.nan

# Apply the function to fill 'Cuisine Types'
Quebec1_df['Cuisine Types'] = Quebec1_df.apply(fill_cuisine, axis=1)

Quebec1_df['Phone'] = pd.to_numeric(Quebec1_df['Phone'], errors='coerce').fillna(np.nan).astype('Int64').astype(str)

Quebec1_df['City']='Quebec'
# Print the updated DataFrame
Quebec1_df.head()
# Out:
#               Name                                   Categories  \
# 0   Le Fin Gourmet  Canadian (New), Burgers, Breakfast & Brunch
# 1       L'Oeuforie              Steakhouses, Breakfast & Brunch
# 2     Casa Grecque                                        Greek
# 3  Le Soleil Rouge                           Breakfast & Brunch
# 4      Chez Ashton               Burgers, Hot Dogs, Poutineries
#
#         Cuisine Types   Nationalities  Rating  \
# 0             Burgers  Canadian (New)     4.5
# 1         Steakhouses              NA     4.0
# 2               Greek           Greek     4.0
# 3  Breakfast & Brunch              NA     5.0
# 4             Burgers              NA     4.0
#
#                                       Address  Res_Latitude  Res_Longitude  \
# 0            774 Rue Raoul-Jobin, Quebec City     46.806850     -71.245840
# 1       850 Boulevard Pierre-Bertrand, Vanier     46.826615     -71.273329
# 2  955 Boulevard Pierre-Bertrand, Quebec City     46.827170     -71.275680
# 3       380A Avenue Turcotte, Ville de Québec     46.821480     -71.257520
# 4    550 Boulevard Wilfrid-Hamel, Quebec City     46.821440     -71.251607
#
#    Reviews     Distance        Phone  Closed Price    City
# 0       15  2175.481757  14186825849   False    $$  Quebec
# 1        7   897.748230  14186814419   False    $$  Quebec
# 2        5  1108.444575  14185271210   False    $$  Quebec
# 3        2   450.240401         <NA>   False    $$  Quebec
# 4        1   908.555722  14186480895   False    $$  Quebec

# %%
Quebec1_df['Res_Latitude'] = Quebec1_df['Res_Latitude'].round(6)
Quebec1_df['Res_Longitude'] = Quebec1_df['Res_Longitude'].round(6)
Quebec1_df['Distance']=Quebec1_df['Distance'].round(2)

# %%
print(Quebec1_df.isnull().sum())
Quebec1_df
# Out:
# Name             0
# Categories       0
# Cuisine Types    0
# Nationalities    0
# Rating           0
# Address          0
# Res_Latitude     0
# Res_Longitude    0
# Reviews          0
# Distance         0
# Phone            0
# Closed           0
# Price            0
# City             0
# dtype: int64
#                      Name                                   Categories  \
# 0          Le Fin Gourmet  Canadian (New), Burgers, Breakfast & Brunch
# 1              L'Oeuforie              Steakhouses, Breakfast & Brunch
# 2            Casa Grecque                                        Greek
# 3         Le Soleil Rouge                           Breakfast & Brunch
# 4             Chez Ashton               Burgers, Hot Dogs, Poutineries
# ..                    ...                                          ...
# 352              Le Dijon                                       French
# 353         Pizza Passion                                        Pizza
# 354          Sushi Oshima                         Japanese, Sushi Bars
# 355         Pizza Passion                                        Pizza
# 356  Restaurant Normandin                                           NA
#
#           Cuisine Types   Nationalities  Rating  \
# 0               Burgers  Canadian (New)     4.5
# 1           Steakhouses              NA     4.0
# 2                 Greek           Greek     4.0
# 3    Breakfast & Brunch              NA     5.0
# 4               Burgers              NA     4.0
# ..                  ...             ...     ...
# 352              French          French     4.0
# 353               Pizza              NA     4.5
# 354          Sushi Bars        Japanese     4.5
# 355               Pizza              NA     4.0
# 356                  NA              NA     3.5
#
#                                           Address  Res_Latitude  \
# 0                774 Rue Raoul-Jobin, Quebec City     46.806850
# 1           850 Boulevard Pierre-Bertrand, Vanier     46.826615
# 2      955 Boulevard Pierre-Bertrand, Quebec City     46.827170
# 3           380A Avenue Turcotte, Ville de Québec     46.821480
# 4        550 Boulevard Wilfrid-Hamel, Quebec City     46.821440
# ..                                            ...           ...
# 352              7900 Rue du Marigot, Quebec City     46.883743
# 353     1450 Boulevard Père-Lelièvre, Quebec City     46.883630
# 354             16, rue Georges-Muir, Quebec City     46.899349
# 355         5425 Avenue des Platanes, Quebec City     46.883628
# 356  15021 Boulevard Henri Bourassa, Charlesbourg     46.881569
#
#      Res_Longitude  Reviews  Distance        Phone  Closed Price    City
# 0       -71.245840       15   2175.48  14186825849   False    $$  Quebec
# 1       -71.273329        7    897.75  14186814419   False    $$  Quebec
# 2       -71.275680        5   1108.44  14185271210   False    $$  Quebec
# 3       -71.257520        2    450.24         <NA>   False    $$  Quebec
# 4       -71.251607        1    908.56  14186480895   False    $$  Quebec
# ..             ...      ...       ...          ...     ...   ...     ...
# 352     -71.307739        5   1538.98  14187812988   False    $$  Quebec
# 353     -71.282465        3   1789.00  14187812555   False    $$  Quebec
# 354     -71.305344        3    659.02  14188413838   False    $$  Quebec
# 355     -71.282464        2   1789.22  14186224447   False    $$  Quebec
# 356     -71.287918        3   1768.22  14186267216   False    $$  Quebec
#
# [357 rows x 14 columns]

# %%
Quebec1_df.to_csv('../data/Quebec.csv', index=False)

# %%
Quebec1_df.to_excel('../data/Quebec.xlsx', index=False)  # Specify the output file name and disable index column
